# %% [markdown]
# ## 4장 노트정리
#
# 이 파일은 4장 학습하면서 실행한 내용을 정리한 것이다.
#
# 날짜: 2025.9.9
#
# 학과: 컴퓨터공학과
#
# 학번: 202210558
#
# 저자: 박로사

# %% [markdown]
# ### 파이썬 자료구조란?
# • 자료를 표현하고 처리하기 위해 사용되는 구조
#
# • 자료를 효율적으로 처리하고 저장하는 데 사용
#
# • 파이썬에서 사용되는 기본 자료 구조
#
# -문자열(string) : str = ‘abcde’ 홑/겹 따옴표로 묶인 문자열
#
# -리스트(list) : list = [ 1, 2, 3, 4] 순서가 있는 원소(객체)의 목록
#
# -튜플(tuple) tuple = (1,2,3) immutable 한 데이터의 쌍
#
# -딕셔너리(dictionary) dic = {‘a’:1, ‘b’:23, ‘c’: 32} 유일한 키로 이루어진 키:값의 집합
#
# -집합(set) set = {1,5,3,2} 유일한 값들의 집합

# %% [markdown]
# ### 문자열
# • 다수의 문자를 표현하기 위한 자료구조
# ![image.png](attachment:image.png)

# %% [markdown]
# • '' 또는 ""로 둘러싼다: "abc", 'hello'
# • '''(""") 부터 '''(""")까지 문자: 문자열이 두 줄 이상일 때 주로 사용
# ![image.png](attachment:image.png)

# %% [markdown]
#  #### 문자열 요소(문자)를 개별적으로 사용하기-index

# %%
>>> word = 'Python'
>>> word[0]
'P'
>>> word[5]
'n'

# %%
>>> word = 'Python'
>>> word[-1]
'n'
>>> word[-6]
'P'

# %% [markdown]
# #### 문자열 슬라이싱(잘라내기)

# %%
>>> word = 'Python'
>>> word[0:2]
'Py'
>>> word[2:5]
'tho'
>>> word[:2]
'Py'
>>> word[4:]
'on'
>>> word[-2]
'o'
>>> word[:2]+word[2:]
'Python'

# %% [markdown]
# #### 문자열 인덱싱과 슬라이싱 오류

# %%
>>> word[42]
Traceback (most recent call last):
  File "<python-input-13>", line 1, in <module>
    word[42]
    ~~~~^^^^
IndexError: string index out of range

# %%
>>> word[4:42]
'on'
>>> word[42:]
''

# %% [markdown]
# #### 문자열은 수정 불가-immutable

# %%
>>> word[0] = 'J'
Traceback (most recent call last):
  File "<python-input-16>", line 1, in <module>
    word[0] = 'J'
    ~~~~^^^
TypeError: 'str' object does not support item assignment

# %% [markdown]
# #### 슬라이싱을 이용하여 새로운 문자열 만들기

# %%
>>> word = 'Python'
>>> word2 = 'J' + word[1:]
>>> word2
'Jython'

# %% [markdown]
# #### 문자열 길이 확인 -len()

# %%
>>> s = 'smiles'
>>> len(s)
6

# %% [markdown]
# #### index를이용하여문자열의문자를역순으로만들기

# %%
## 변수초기화부분##
 outStr = "" #출력문자열(빈문자열)
 count, i = 0, 0
 ## 메인코드부분##
 inStr = input("Type string : ")
 count = len(inStr)#문자열길이
for i in range(0, count) :
    outStr += inStr[count – (i + 1)]#마지막문자부터추출하여합치기
print("Reversed string : %s" % outStr)

# %% [markdown]
# #### 문자열에서문자조사하기– in/not in 연산자(멤버연산자)

# %%
>>> 'a' in 'cat'
True
>>> 'a' not in 'can'
False

# %% [markdown]
# #### 문자열과 메소드 -dir(str),help(str.method)

# %% [markdown]
# •파이썬은객체지향언어이므로객체(object)가많이사용된다
#
# •객체는변수와함수를묶은것이다. 문자열도객체다
#
# •객체와관련된함수를메소드라하며객체.함수()로호출한다

# %% [markdown]
# #### 문자열 구성 파악하기

# %% [markdown]
# '123'.isdigit() -> 문자열이숫자인가?
#
# 'abcABC'.isalpha() -> 문자열이문자인가?
#
# 'Ab122'.isalnum() -> 문자열이문자+숫자혼합인가?
#
# 'AB'.isupper() -> 문자열이대문자인가?
#
# 'ab'.islower() -> 문자열이소문자인가?
#
# ' '.isspace() -> 문자열이공백인가?

# %% [markdown]
# #### 문자열을대소문자로변환하기

# %% [markdown]
#  str = 'Python programming is easy!'
#
#  str.upper() -> 대문자로변환
#
# str.lower() -> 소문자로변환
#
# str.swapcase() -> 대소문자바꾸기
#
# str.title() -> 첫글자만대문자로변환

# %% [markdown]
# #### 문자열 찾기

# %%
>>> str = 'Python programming is easy!'
>>> str.count('i')
2
>>> str.find('o') 
4
>>> str.rfind('o')
9
>>> str.index('on')
4

# %% [markdown]
# #### 문자열분리하기

# %%
>>> x = 'a bc'
>>> x.split()
['a', 'bc']
>>> x.split('b')
['a ', 'c']

# %% [markdown]
# #### 문자열에서공백제거하기

# %%
>>> str = 'hello'
>>> str.strip()
'hello'
>>> str
'hello'
>>> str.rstrip()
'hello'
>>> str.lstrip()
'hello'

# %% [markdown]
# #### 문자열결합하기

# %%
>>> '*'.join('hello')
'h*e*l*l*o'

# %% [markdown]
# #### 문자열채우기

# %%
>>> '12'.zfill(5)

# %% [markdown]
# #### 문자열 정렬하기

# %%
>>> 'he'.rjust(5)
'   he'
>>> 'he'.ljust(5)
'he   '
>>> 'he'.center(5)
'  he '

# %% [markdown]
# ### 리스트

# %% [markdown]
# 리스트는여러개의데이터를하나의이름으로저장하는자료구조
# ![image.png](attachment:image.png)

# %%
>>> odd = [1, 3, 5, 7, 9]
>>> squares = [1, 4, 9, 16, 25]
>>> squares
[1, 4, 9, 16, 25]
>>> empty = []
>>> empty
[]
>>> a = [1, 'hello', 2, 'world', 1.23]

# %% [markdown]
# #### 리스트의인덱싱(요소접근하기)과슬라이싱(잘라내기)

# %%
>>> squares = [1, 4, 9, 16, 25]
>>> squares[0] 
1
>>> squares[-1]
25
>>> squares[0:3]
[1, 4, 9]
>>> squares[-3:]
[9, 16, 25]

# %% [markdown]
# #### 리스트합치기

# %%
>>> squares + [36, 49, 64, 81, 100]
[1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
>>> a = [1, 2, 3]
>>> b = [4, 5, 6]
>>> a + b
[1, 2, 3, 4, 5, 6]

# %% [markdown]
# #### 리스트의요소 수정, 추가하기

# %%
>>> cubes = [1, 8, 27, 65, 125]
>>> 4 ** 3
64
>>> cubes[3] = 64
>>> cubes
[1, 8, 27, 64, 125]

>>> cubes.append(216)
>>> cubes.append(7 ** 3)
>>> cubes
[1, 8, 27, 64, 125, 216, 343]

# %% [markdown]
# #### 리스트의요소 수정

# %%
>>> letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
>>> letters
['a', 'b', 'c', 'd', 'e', 'f', 'g']
>>> letters[2:5] = ['C', 'D', 'E']
>>> letters
['a', 'b', 'C', 'D', 'E', 'f', 'g']
>>> letters[2:5] = []
>>> letters
['a', 'b', 'f', 'g']
>>> letters[:] = []
>>> letters
[]

# %% [markdown]
# #### 중첩 리스트

# %%
>>> a = ['a', 'b', 'c']
>>> n = [1, 2, 3]
>>> x = [a, n]
>>> x
[['a', 'b', 'c'], [1, 2, 3]] 리스트요소가리스트이다
>>> x[0]
['a', 'b', 'c']
>>> x[0][1] 중첩리스트요소지정
'b'

# %% [markdown]
# #### 2차원 리스트

# %%
list2d = [[1,2,3],
[4,5,6],
[7,8,9]]
>>> list2d[0][0]
1
>>> list2d[2][2]
9

# %% [markdown]
# #### 내장함수를이용한리스트다루기

# %%
>>> letters = ['a', 'b', 'c', 'd']
>>> len(letters)
 4

>>> num = [1, 2, 3, 4, 5]
>>> sum(num)
15
>>> min(num)
1
>>> max(num)
5

# %% [markdown]
# #### 리스트 메소드

# %%
사용법 확인하기
>>>help(list.sort)

# %% [markdown]
# #### 리스트 요소 순서 나열

# %%
cars = ['taxi', 'sedan', 'bus', 'truck']
cars.sort()
print(cars)

cars.sort(reverse=True)
print(cars)

print("Here is the original list:")
print(cars)
print("\nHere is the sorted list:")
print(sorted(cars))
print("\nHere is the original list again:")
print(cars)
# Out:
# ['bus', 'sedan', 'taxi', 'truck']
# ['truck', 'taxi', 'sedan', 'bus']
# Here is the original list:
# ['truck', 'taxi', 'sedan', 'bus']
#
# Here is the sorted list:
# ['bus', 'sedan', 'taxi', 'truck']
#
# Here is the original list again:
# ['truck', 'taxi', 'sedan', 'bus']

# %% [markdown]
# #### 리스트 역순으로 출력하기

# %%
cars = ['taxi', 'sedan', 'bus', 'truck ']
print(cars)
cars.reverse()
print(cars)
# Out:
# ['taxi', 'sedan', 'bus', 'truck ']
# ['truck ', 'bus', 'sedan', 'taxi']

# %% [markdown]
# #### 리스트 관련 에러

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles[3])

Traceback (most recent call last):
File "motorcycles.py", line 3, in <module>
print(motorcycles[3])
IndexError: list index out of range

# %% [markdown]
# #### 리스트 내포

# %% [markdown]
# • 리스트안에for문을포함하여한줄로리스트를만드는방법
#
# • [표현식 for 항목 in 반복객체]
#
# • [표현식 for 항목 in 반복객체 if 조건문]
#
# • [표현식 if 조건문 else 문장 for 항목 in 반복객체]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 튜플
